# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/Telco-Customer-Churn clean data.csv")

# %%
df.head()
# Out:
#    customerID  Gender Senior Citizen Partner Dependents  Tenure Phone Service  \
# 0  7590-VHVEG  Female             No     Yes         No       1            No
# 1  5575-GNVDE    Male             No      No         No      34           Yes
# 2  3668-QPYBK    Male             No      No         No       2           Yes
# 3  7795-CFOCW    Male             No      No         No      45            No
# 4  9237-HQITU  Female             No      No         No       2           Yes
#
#      Multiple Lines Internet Service Online Security  ... Device Protection  \
# 0  No phone service              DSL              No  ...                No
# 1                No              DSL             Yes  ...               Yes
# 2                No              DSL             Yes  ...                No
# 3  No phone service              DSL             Yes  ...               Yes
# 4                No      Fiber optic              No  ...                No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         7043 non-null   object
#  1   Gender             7043 non-null   object
#  2   Senior Citizen     7043 non-null   object
#  3   Partner            7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   Tenure             7043 non-null   int64
#  6   Phone Service      7043 non-null   object
#  7   Multiple Lines     7043 non-null   object
#  8   Internet Service   7043 non-null   object
#  9   Online Security    7043 non-null   object
#  10  Online Backup      7043 non-null   object
#  11  Device Protection  7043 non-null   object
#  12  Tech Support       7043 non-null   object
#  13  Streaming TV       7043 non-null   object
#  14  Streaming Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
# ...

# %%
#As We Can See No Null Value In the Dataset  So We Can Move Forward

# %%
df.isnull().sum()
# Out:
# customerID           0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %%
df.shape
# Out:
# (7043, 21)

# %%
# There Are  Columns And 7043 Rows And this Is  Large Data

# %%
# Now We Check Statistical Summary

# %%
df.describe(include='all')
# Out:
#         customerID Gender Senior Citizen Partner Dependents       Tenure  \
# count         7043   7043           7043    7043       7043  7043.000000
# unique        7043      2              2       2          2          NaN
# top     3186-AJIEK   Male             No      No         No          NaN
# freq             1   3555           5901    3641       4933          NaN
# mean           NaN    NaN            NaN     NaN        NaN    32.371149
# std            NaN    NaN            NaN     NaN        NaN    24.559481
# min            NaN    NaN            NaN     NaN        NaN     0.000000
# 25%            NaN    NaN            NaN     NaN        NaN     9.000000
# 50%            NaN    NaN            NaN     NaN        NaN    29.000000
# 75%            NaN    NaN            NaN     NaN        NaN    55.000000
# max            NaN    NaN            NaN     NaN        NaN    72.000000
#
#        Phone Service Multiple Lines Internet Service Online Security  ...  \
# ...

# %%
# Average Tenure AGe 32.37 MOnth Tenure

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool

# %%
# Q1. What is the overall distribution of customer churn?

# %%
plt.figure(figsize=(6,4))
sns.countplot (x="Churn",data=df)

plt.title("Customer Churn Distribution")
plt.xlabel('Churn')
plt.ylabel('Number Of Customers')

plt.show()

# %% [markdown]
# #Insight
#
#  - the Majority customers Are Retained
#  - The Churn Ratre Is BAlanced

# %%
#Does gender affect customer churn?

# %%
sns.countplot(x='Gender',hue = "Churn", data=df)
plt.title("Gender VS Customer churn")
plt.show()

# %% [markdown]
# Insights
# - From the Graph We Can See Similar Churn Rate  In Both Gender
# - In Total 7043 Customer are Churn.

# %%
#Q3. Are senior citizens more likely to churn?

# %%
plt.figure(figsize=(6,4))

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Senior Citizen',hue ="Churn",data=df)
plt.title('Senior Citizen  VS Churn ')
plt.show()

# %% [markdown]
# #Insight
#
#  - The Majority Customers Are Not Senior And Most Of Did not churn
#  - NUmber OF Senior Citizen Is much Lower than Non Senior Customers
#  - This Suggest That Senior Citizen HAve higher Churn Rate non Senior Customers Shoew Better Retention

# %%
#does having a partner affect churn?

# %%
sns.countplot(x="Partner",hue="Churn",data=df)
plt.title("Partner VS churn")
plt.xlabel("Partner")
plt.ylabel("Number Of Customer Churn")
plt.show()

# %% [markdown]
# #Insight
# - Customers With Partner HAs Lower churn Rate Compare To Without Partner
# - also Both groups Have Higher customer
# - Those customer have PArner Status have Less Churn Rate

# %%
#Do customers with dependents churn less?

# %%
sns.countplot(x="Dependents", hue="Churn",data=df)
plt.title("Dependent VS Churn Rate")
plt.xlabel("Dependents")
plt.ylabel("Count Rate")
plt.show()

# %% [markdown]
# # Insight
#  - In This graph It Shows That those Customers Are Dependent are Likely Less churn Rate whereas cusrtomers Thats Independnt Are  Likely to More churn
#  - As Per graph they want To Settle at great Place thats why They Are Switching
#  At other Side
#  - those are dependant are Likely To switch / Churn

# %%
#Which contract type has the highest churn?

# %%
sns.countplot(x="Contract",hue="Churn",data=df)
plt.title("Contract Type Churn")
plt.xlabel("contract Type")
plt.ylabel("NO.OF Customer Churn")
# Out:
# Text(0, 0.5, 'NO.OF Customer Churn')

# %% [markdown]
# Insight
#
# - Month To Month Contract type HAve ARE highest churn Rate  cases
#  thats Shows customeers Without Long Term customers are Not Loyal.
#
#  - One year contract Type churn Is aignificantly Lower As compare To Month and Month Customers
#
#  - Two Year contract Very Few Customers Are Churn Rate in Two Year Contract this Show Longer the contract Customers Will be Loyal Or easy to retained.
#
#  - Customers With Longer Term Contract arer less likely to churn while month to Month Customers HAVE high Risk Of Churn

# %%
# Does phone service affect churn?

# %%
sns.countplot (x="Phone Service",hue="Churn",data=df)
plt.title("Phone service Churn rate ")
plt.ylabel("Phone service ")
plt.show()

# %% [markdown]
# #Insight
#
# - Analysis Of this Graph Most customer have Phone Service .
# - customers With more Phone Service Have Higher Churn Rate Most Phone SerVices  - most Phone Service Customers Are Retained . Customers Are Without Phone Service Almost Stay  Tihs IS'nt THE Main Reason for the  Churned

# %%
# Do customers with higher monthly charges churn more?

# %%
sns.boxplot(x="Churn",y="Monthly Charges",data =df)
plt.title("Monthly Charges VS Churn")
plt.show()

# %% [markdown]
# #Insight
#
# - customers who churn are generally pay high monthly chargesc
# - company should focuas on High Paying customers And Improve Retention Through Support
# - price Factor OF Monthly Charges Is Most important To Avoid Or Churn rate

# %%
# Does customer tenure affect churn?

# %%
df.columns
# Out:
# Index(['customerID', 'Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
sns.boxplot(x='Churn', y='Tenure', data=df)
plt.title("Tenure VS Churn")
plt.show()

# %% [markdown]
# #Insight
#  - the Customers Who Churn Has Lower Tenure the Longer the tenure The Chances Of churn Is likely to Be Low
#  - No churn Group Has Wider Of tenure values Means retained retention Is high.
#  - A Few long Tenure Customers Are Churn thats Mean Even If You Have Loyal customers Still Some Customers Are Churned Due TO Pricing.
